# %%
text_file = open("fb_data.txt", "r")

# %%
with open('fb_data.txt') as f:
    mylist = [line.rstrip('\n') for line in f]

# %%
mylist[0]
# Out:
# 'Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY'

# %%
with open('fb_label.txt') as f:
    labels = [line.rstrip('\n') for line in f]

# %%
mylist[0]
# Out:
# 'Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY'

# %%
labels[0]
# Out:
# 'O'

# %%
mylist2=[s.lower() for s in mylist]

# %%
import re

# %%
mylist=[re.sub(r'\d+', '', s) for s in mylist2]

# %%
mylist2[0]
# Out:
# 'drug runners and  a us senator have something to do with the murder httpwwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt the state attorney knows now so will you get ypur copy today'

# %%
import string
mylist2=[s.translate(str.maketrans('','',string.punctuation)) for s in mylist]

# %%
mylist=[s.strip() for s in mylist2]

# %%
import nltk
import re
temp =[]
snow = nltk.stem.SnowballStemmer('english')
for sentence in mylist:
    sentence = sentence.lower()                 # Converting to lowercase
    cleanr = re.compile('<.*?>')
    sentence = re.sub(cleanr, ' ', sentence)        #Removing HTML tags
    sentence = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    sentence = re.sub(r'[.|,|)|(|\|/]',r' ',sentence)        #Removing Punctuations
    
    words = [snow.stem(word) for word in sentence.split() if word not in stopwords.words('english')]   # Stemming and removing stopwords
    temp.append(words)
    
final_X = temp

# %%
import warnings
warnings.filterwarnings("ignore")                     #Ignoring unnecessory warnings

import numpy as np                                  #for large and multi-dimensional arrays
import pandas as pd                                 #for data manipulation and analysis
import nltk                                         #Natural language processing tool-kit

from nltk.corpus import stopwords                   #Stopwords corpus
from nltk.stem import PorterStemmer                 # Stemmer

from sklearn.feature_extraction.text import CountVectorizer          #For Bag of words
from sklearn.feature_extraction.text import TfidfVectorizer          #For TF-IDF
from gensim.models import Word2Vec

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
final_X[0]
# Out:
# ['drug',
#  'runner',
#  'us',
#  'senat',
#  'someth',
#  'murder',
#  'httpwwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt',
#  'state',
#  'attorney',
#  'know',
#  'get',
#  'ypur',
#  'copi',
#  'today']

# %%
sent = []
for row in final_X:
    sequ = ''
    for word in row:
        sequ = sequ + ' ' + word
    sent.append(sequ)

final_X = sent
print(final_X[1])
# Out:
#  here singl add kindl read th centuri stori ghost round island man frenchamerican indian dog sled transport woman across ice mackinac island cheboygan ghost

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(binary=True)
cv.fit(final_X)
X = cv.transform(final_X)

# %%
X.shape
# Out:
# (1003, 2306)

# %%
set(final_X[0])
# Out:
# {'attorney',
#  'copi',
#  'drug',
#  'get',
#  'httpwwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt',
#  'know',
#  'murder',
#  'runner',
#  'senat',
#  'someth',
#  'state',
#  'today',
#  'us',
#  'ypur'}

# %%
x=[]
for l in final_X:
  x.extend(l)

# %%
x
# Out:
# ['drug',
#  'runner',
#  'us',
#  'senat',
#  'someth',
#  'murder',
#  'httpwwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt',
#  'state',
#  'attorney',
#  'know',
#  'get',
#  'ypur',
#  'copi',
#  'today',
#  'here',
#  'singl',
#  'add',
#  'kindl',
#  'read',
#  'th',
#  'centuri',
#  'stori',
#  'ghost',
#  'round',
#  'island',
#  'man',
#  'frenchamerican',
#  'indian',
#  'dog',
#  'sled',
#  'transport',
#  'woman',
#  'across',
#  'ice',
#  'mackinac',
#  'island',
#  'cheboygan',
#  'ghost',
#  'tire',
#  'nonfict',
#  'check',
#  'httpwwwamazoncomsrefnbsbnossurlsearchaliasdapsfieldkeywordsdanielleleezwisslerxi',
#  'ghost',
#  'round',
#  'island',
#  'suppos',
#  'nonfict',
#  'barn',
#  'nobl',
#  'version',
#  'kindl',
#  'much',
#  'expens',
#  'kindl',
#  'maria',
#  'mean',
#  'nook',
#  'care',
#  'book',
#  'buy',
#  'kindl',
#  'piec',
#  'electron',
#  'vice',
#  'versa',
#  'love',
#  'kindl',
#  'peopl',
#  'swear',
#  'nook',
#  'like',
#  'color',
#  'screenm',
#  'want',
#  'eread',
#  'reader',
#  'dont',
#  'need',
#  'color',
#  'kindl',
#  'batteri',
#  'last',
#  'longer',
#  'unit',
#  'isnt',
#  'heavi',
#  'make',
#  'differ',
#  'read',
#  'hour',
#  'kindl',
#  'awesom',
#  'mine',
#  'great',
#  'love',
#  'mine',
#  'meh',
#  'think',
#  'singl',
#  'bad',
#  'idea',
#  'big',
#  'name',
#  'author',
#  'alreadi',
#  'domin',
#  'market',
#  'huge',
#  'factor',
#  'let',
#  'compet',
#  'price',
#  'point',
#  'indi',
#  'author',
#  'albeit',
#  'give',
#  'less',
#  'content',
#  'money',
#  'daugjhter',
#  'love',
#  'sure',
#  'got',
#  'updat',
#  'dont',
#  'locat',
#  'number',
#  'unless',
#  'press',
#  'menu',
#  'button',
#  'also',
#  'dont',
#  'page',
#  'number',
#  'someth',
#  'wrong',
#  'got',
#  'kindl',
#  'xmas',
#  'love',
#  'never',
#  'much',
#  'book',
#  'reader',
#  'fun',
#  'th',
#  'book',
#  'sinc',
#  'christma',
#  'dont',
#  'patienc',
#  'kindl',
#  'singl',
#  'im',
#  'gonna',
#  'read',
#  'need',
#  'least',
#  'page',
#  'love',
#  'new',
#  'singl',
#  'read',
#  'jodi',
#  'picoult',
#  'right',
#  'wait',
#  'till',
#  'tuesday',
#  'new',
#  'book',
#  'come',
#  'fan',
#  'kindl',
#  'singl',
#  'clog',
#  'kindl',
#  'book',
#  'page',
#  'tough',
#  'sort',
#  'fulllegnth',
#  'new',
#  'releas',
#  'mani',
#  'singl',
#  'best',
#  'thing',
#  'sinc',
#  'slice',
#  'bread',
#  'love',
#  'kindl',
#  'anybodi',
#  'tell',
#  'free',
#  'chapter',
#  'tick',
#  'toc',
#  'patterson',
#  'summari',
#  'chapter',
#  'real',
#  'dealmi',
#  'kindl',
#  'jump',
#  'read',
#  'page',
#  'read',
#  'real',
#  'big',
#  'textthank',
#  'love',
#  'kindl',
#  'also',
#  'enoy',
#  'new',
#  'york',
#  'time',
#  'articlethought',
#  'provok',
#  'well',
#  'kindl',
#  'love',
#  'yeah',
#  'u',
#  'get',
#  'kindl',
#  'hard',
#  'put',
#  'sumtim',
#  'r',
#  'mani',
#  'book',
#  'choos',
#  'luv',
#  'mine',
#  'well',
#  'singl',
#  'anyon',
#  'know',
#  'legthen',
#  'time',
#  'kindl',
#  'go',
#  'screen',
#  'saver',
#  'mood',
#  'love',
#  'kindlenot',
#  'sure',
#  'got',
#  'updat',
#  'though',
#  'dont',
#  'see',
#  'differ',
#  'read',
#  'color',
#  'dont',
#  'need',
#  'color',
#  'read',
#  'kindl',
#  'perfect',
#  'singl',
#  'ive',
#  'read',
#  'realli',
#  'fan',
#  'oen',
#  'way',
#  'anotheri',
#  'like',
#  'read',
#  'read',
#  'whatev',
#  'look',
#  'interest',
#  'time',
#  'saylov',
#  'kindl',
#  'sure',
#  'bad',
#  'arent',
#  'offer',
#  'origin',
#  'kindl',
#  'seem',
#  'like',
#  'us',
#  'got',
#  'bandwagon',
#  'first',
#  'left',
#  'dust',
#  'love',
#  'kindl',
#  'wwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt',
#  'solv',
#  'mysteri',
#  'get',
#  'copi',
#  'today',
#  'amazon',
#  'kindl',
#  'arent',
#  'miss',
#  'thing',
#  'tri',
#  'game',
#  'suck',
#  'coupl',
#  'game',
#  'kindleon',
#  'problem',
#  'famili',
#  'seem',
#  'think',
#  'put',
#  'dont',
#  'make',
#  'free',
#  'money',
#  'know',
#  'let',
#  'get',
#  'straightkindl',
#  'game',
#  'devic',
#  'dont',
#  'jump',
#  'shark',
#  'kindlepleas',
#  'dont',
#  'true',
#  'andersalthough',
#  'money',
#  'otherwis',
#  'wouldnt',
#  'exist',
#  'play',
#  'game',
#  'kindl',
#  'app',
#  'ipad',
#  'mr',
#  'meisch',
#  'ok',
#  'calm',
#  'p',
#  'yes',
#  'game',
#  'one',
#  'tri',
#  'kindl',
#  'along',
#  'gazillion',
#  'book',
#  'either',
#  'text',
#  'base',
#  'simpl',
#  'time',
#  'killer',
#  'far',
#  'actual',
#  'decent',
#  'well',
#  'ive',
#  'tri',
#  'anyway',
#  'ive',
#  'heard',
#  'aw',
#  'onesi',
#  'one',
#  'tout',
#  'ok',
#  'favorit',
#  'tri',
#  'tripl',
#  'town',
#  'addict',
#  'one',
#  'decent',
#  'enough',
#  'begin',
#  'easi',
#  'far',
#  'middl',
#  'good',
#  'end',
#  'level',
#  'killer',
#  'right',
#  'origin',
#  'kindl',
#  'nd',
#  'generat',
#  'free',
#  'game',
#  'also',
#  'blackjack',
#  'poker',
#  'word',
#  'game',
#  'love',
#  'everi',
#  'word',
#  'video',
#  'poker',
#  'read',
#  'standalon',
#  'interact',
#  'fiction',
#  'text',
#  'adventur',
#  'game',
#  'know',
#  'onlin',
#  'one',
#  'dont',
#  'g',
#  'id',
#  'like',
#  'play',
#  'away',
#  'wifi',
#  'kindl',
#  'book',
#  'stop',
#  'make',
#  'somth',
#  'notleav',
#  'game',
#  'mobl',
#  'devic',
#  'anyon',
#  'develop',
#  'game',
#  'st',
#  'generat',
#  'kindl',
#  'im',
#  'go',
#  'get',
#  'new',
#  'one',
#  'play',
#  'gameseven',
#  'though',
#  'would',
#  'like',
#  'option',
#  'play',
#  'tripl',
#  'town',
#  'funif',
#  'dont',
#  'want',
#  'game',
#  'dont',
#  'get',
#  'game',
#  'kindl',
#  'enjoy',
#  'also',
#  'enjoy',
#  'fact',
#  'travel',
#  'dont',
#  'take',
#  'multipl',
#  'devic',
#  'order',
#  'stay',
#  'busi',
#  'airplan',
#  'ride',
#  'car',
#  'dont',
#  'like',
#  'game',
#  'dont',
#  'buy',
#  'game',
#  'fun',
#  'abl',
#  'play',
#  'game',
#  'dont',
#  'feel',
#  'like',
#  'read',
#  'us',
#  'fanci',
#  'schmanci',
#  'smart',
#  'phone',
#  'kindl',
#  'option',
#  'download',
#  'play',
#  'game',
#  'ruin',
#  'experi',
#  'kindl',
#  'complain',
#  'doesnt',
#  'make',
#  'sens',
#  'yes',
#  'de',
#  'ra',
#  'get',
#  'ipad',
#  'bought',
#  'love',
#  'play',
#  'game',
#  'kindl',
#  'love',
#  'tripl',
#  'town',
#  'peopl',
#  'love',
#  'complain',
#  'everyth',
#  'like',
#  'someon',
#  'said',
#  'dont',
#  'want',
#  'game',
#  'dont',
#  'get',
#  'duh',
#  'umhow',
#  'play',
#  'kindl',
#  'got',
#  'much',
#  'fun',
#  'addict',
#  'play',
#  'origin',
#  'download',
#  'cent',
#  'harder',
#  'play',
#  'dont',
#  'color',
#  'pretend',
#  'peopl',
#  'may',
#  'want',
#  'game',
#  'kindlethat',
#  'fine',
#  'prefer',
#  'use',
#  'kindl',
#  'eread',
#  'love',
#  'kindl',
#  'dont',
#  'color',
#  'kindlemayb',
#  'wait',
#  'other',
#  'say',
#  'like',
#  'ok',
#  'bit',
#  'kindl',
#  'month',
#  'old',
#  'went',
#  'kaput',
#  'wont',
#  'turn',
#  'call',
#  'custom',
#  'servic',
#  'replac',
#  'immedi',
#  'question',
#  'ask',
#  'love',
#  'kindleread',
#  'play',
#  'scrabblelov',
#  'thing',
#  'fitzwat',
#  'gale',
#  'one',
#  'color',
#  'kindl',
#  'sure',
#  'love',
#  'kindl',
#  'love',
#  'kindl',
#  'best',
#  'present',
#  'ever',
#  'didnt',
#  'even',
#  'ask',
#  'one',
#  'mum',
#  'know',
#  'well',
#  'love',
#  'new',
#  'g',
#  'kindl',
#  'love',
#  'kindl',
#  'old',
#  'school',
#  'kindl',
#  'life',
#  'kindl',
#  'one',
#  'prize',
#  'possess',
#  'belov',
#  'got',
#  'one',
#  'birthday',
#  'awesom',
#  'put',
#  'book',
#  'itbtw',
#  'anyon',
#  'know',
#  'get',
#  'book',
#  'onto',
#  'kindl',
#  'previous',
#  'bought',
#  'paper',
#  'love',
#  'favorit',
#  'thing',
#  'kindl',
#  'love',
#  'love',
#  'kindl',
#  'easi',
#  'conveni',
#  'take',
#  'everywher',
#  '♥',
#  'husband',
#  'bought',
#  'one',
#  'use',
#  'daili',
#  'awesom',
#  'word',
#  'say',
#  'love',
#  'kindl',
#  'love',
#  'kindl',
#  'wish',
#  'time',
#  'read',
#  'pleasurenot',
#  'school',
#  'think',
#  'begin',
#  'great',
#  'countri',
#  'song',
#  'day',
#  'like',
#  'kindl',
#  'day',
#  'total',
#  'fan',
#  'clara',
#  'book',
#  'gotten',
#  'kindl',
#  'check',
#  'amazon',
#  'loos',
#  'bookmark',
#  'kindl',
#  'thing',
#  'allow',
#  'bed',
#  'night',
#  'stay',
#  'read',
#  'til',
#  'eye',
#  'wont',
#  'stay',
#  'open',
#  'kindl',
#  'cara',
#  'bolton',
#  'unfortun',
#  'repurchas',
#  'yesterday',
#  'three',
#  'book',
#  'figur',
#  'worth',
#  'invest',
#  'love',
#  'everi',
#  'minut',
#  'spend',
#  'new',
#  'friend',
#  'kindl',
#  'read',
#  'sleep',
#  'everi',
#  'night',
#  'love',
#  'beauti',
#  'red',
#  'leather',
#  'light',
#  'cover',
#  'never',
#  'leav',
#  'home',
#  'wo',
#  'werent',
#  'typ',
#  'spell',
#  'error',
#  'missingspac',
#  'stuff',
#  'everi',
#  'singl',
#  'book',
#  'matter',
#  'price',
#  'kindl',
#  'would',
#  'best',
#  'thing',
#  'ever',
#  'would',
#  'love',
#  'program',
#  'allow',
#  'us',
#  'sell',
#  'back',
#  'read',
#  'book',
#  'game',
#  'kindl',
#  'credit',
#  'would',
#  'love',
#  'program',
#  'allow',
#  'us',
#  'sell',
#  'back',
#  'read',
#  'book',
#  'game',
#  'kindl',
#  'credit',
#  'drop',
#  'qualiti',
#  'medic',
#  'mysteri',
#  'cent',
#  'kindl',
#  'show',
#  'price',
#  'noth',
#  'qualiti',
#  'write',
#  'titl',
#  'floater',
#  'confus',
#  'joe',
#  'konrath',
#  'joe',
#  'waumgauh',
#  'floater',
#  'ipad',
#  'kindl',
#  'app',
#  'awesom',
#  'realli',
#  'like',
#  'kindl',
#  'difficult',
#  'write',
#  'sentenc',
#  'use',
#  'word',
#  'game',
#  'due',
#  'tini',
#  'letter',
#  'overal',
#  'kindl',
#  'wonder',
#  'love',
#  'mine',
#  'enough',
#  'marri',
#  'dam',
#  'thing',
#  'day',
#  'may',
#  'one',
#  'would',
#  'happi',
#  'think',
#  'even',
#  'compos',
#  'songtil',
#  'thenwhawha',
#  'love',
#  'kindl',
#  'love',
#  'mine',
#  'thank',
#  'margi',
#  'love',
#  'thank',
#  'john',
#  'zaffino',
#  'love',
#  'kindl',
#  'ever',
#  'sinc',
#  'first',
#  'given',
#  'mine',
#  'almost',
#  'yrs',
#  'ago',
#  'love',
#  'kindl',
#  'best',
#  'thing',
#  'invent',
#  'love',
#  'kindl',
#  'best',
#  'thing',
#  'ever',
#  'agre',
#  'love',
#  'kindl',
#  'g',
#  'bought',
#  'kindl',
#  'sister',
#  'love',
#  'read',
#  'excit',
#  'short',
#  'afterward',
#  'friend',
#  'bought',
#  'kindl',
#  'know',
#  'rave',
#  'havent',
#  'put',
#  'get',
#  'book',
#  'easier',
#  'go',
#  'bookstor',
#  'cheaper',
#  'thx',
#  'love',
#  'kindl',
#  'love',
#  'love',
#  'kindlemi',
#  'caveatsi',
#  'miss',
#  'wonder',
#  'artwork',
#  'cover',
#  'paperbacksand',
#  'photo',
#  'magazinesand',
#  'love',
#  'share',
#  'book',
#  'other',
#  'cant',
#  'loan',
#  'young',
#  'adult',
#  'kid',
#  'friendsbummerand',
#  'mani',
#  'archiv',
#  'like',
#  'reread',
#  'book',
#  'love',
#  'kindl',
#  'must',
#  'love',
#  'love',
#  'love',
#  'kindl',
#  'love',
#  'mine',
#  'love',
#  'kindl',
#  'sever',
#  'year',
#  'ask',
#  'stapl',
#  'go',
#  'upgrad',
#  'kindl',
#  'clue',
#  'want',
#  'kindl',
#  'soooo',
#  'bad',
#  'ive',
#  'got',
#  'bday',
#  'want',
#  'list',
#  'site',
#  'help',
#  'got',
#  'book',
#  'categori',
#  'figur',
#  'highlight',
#  'check',
#  'word',
#  'dictionari',
#  'kindl',
#  'rule',
#  'school',
#  'theyr',
#  'coollalalaa',
#  'kindl',
#  'read',
#  'better',
#  'speed',
#  'lalala',
#  'ok',
#  'im',
#  'guess',
#  'fail',
#  'songwrit',
#  'ill',
#  'stick',
#  'read',
#  'kindl',
#  'bet',
#  'there',
#  'book',
#  'download',
#  'yesterday',
#  'kindl',
#  'seem',
#  'far',
#  'away',
#  'sudden',
#  'wait',
#  'time',
#  'half',
#  'use',
#  'love',
#  'kindl',
#  'also',
#  'one',
#  'problem',
#  'favorit',
#  'author',
#  'john',
#  'saul',
#  'robin',
#  'cook',
#  'patricia',
#  ...]

# %%
dic=set(x)

# %%
dic
# Out:
# {'compet',
#  'over',
#  'spark',
#  'weird',
#  'shakespear',
#  'holiday',
#  'write',
#  'confino',
#  'cash',
#  'shark',
#  'mmm',
#  'referenc',
#  'twice',
#  'old',
#  'ortho',
#  'scari',
#  'ellipt',
#  'immedi',
#  'kindlecr',
#  'beat',
#  'ra',
#  'even',
#  'open',
#  'builtin',
#  'lover',
#  'crumb',
#  'shape',
#  'interest',
#  'written',
#  'book',
#  'lesson',
#  'made',
#  'leap',
#  'wall',
#  'refer',
#  'oxford',
#  'itd',
#  'bang',
#  'st',
#  'communiti',
#  'experienc',
#  'jodi',
#  'jeff',
#  'wonder',
#  'stress',
#  'imagin',
#  'simpli',
#  'ukrainian',
#  'crackl',
#  'mayb',
#  'accessori',
#  'sit',
#  'kindlemayb',
#  'ideasomebodi',
#  'adquirido',
#  'stroj',
#  'superior',
#  'fabric',
#  'son',
#  'island',
#  'rep',
#  'enter',
#  'clear',
#  'sept',
#  'upon',
#  'cyr',
#  'treadmil',
#  'fussi',
#  'mejor',
#  'curs',
#  'stroll',
#  'thumbnail',
#  'could',
#  'snow',
#  'todo',
#  'futur',
#  'noooo',
#  'nd',
#  'within',
#  'chair',
#  'act',
#  'hurt',
#  'annoy',
#  'surpris',
#  'involv',
#  'feminin',
#  'hit',
#  'anna',
#  'talk',
#  'graduat',
#  'wife',
#  'safe',
#  'omgi',
#  'ive',
#  'convert',
#  'spend',
#  'archaic',
#  'section',
#  'doabl',
#  'sort',
#  'floater',
#  'drain',
#  'thirst',
#  'pg',
#  'artwork',
#  'area',
#  'goa',
#  'stephani',
#  'head',
#  'breastfeed',
#  'second',
#  'skill',
#  'profil',
#  'flash',
#  'fetish',
#  'concern',
#  'propos',
#  'offic',
#  'screensav',
#  'juli',
#  'collect',
#  'cj',
#  'challeng',
#  'popul',
#  'easili',
#  'snap',
#  'umhow',
#  'tout',
#  'web',
#  'regard',
#  'name',
#  'frame',
#  'incom',
#  'singl',
#  'illiter',
#  'five',
#  'memori',
#  'companion',
#  'bit',
#  'defect',
#  'mode',
#  'prevent',
#  'canada',
#  'hurdl',
#  'compu',
#  'spent',
#  'consol',
#  'autobiographi',
#  'thriller',
#  'fashion',
#  'text',
#  'experi',
#  'somewher',
#  'version',
#  'plastic',
#  'that',
#  'foam',
#  'readinglol',
#  'matter',
#  'mean',
#  'altern',
#  'keurig',
#  'skip',
#  'backlight',
#  'russian',
#  'market',
#  'possess',
#  'childrenthank',
#  'provid',
#  'last',
#  'slight',
#  'neat',
#  'discomfort',
#  'easi',
#  'onto',
#  'honey',
#  'complic',
#  'soo',
#  'havent',
#  'increas',
#  'cost',
#  'pain',
#  'drs',
#  'koontz',
#  'sew',
#  'forc',
#  'averag',
#  'smile',
#  'pool',
#  'never',
#  'tooif',
#  'eye',
#  'alphabet',
#  'thnx',
#  'kindlemak',
#  'dx',
#  'wellthi',
#  'yes',
#  'happend',
#  'instinct',
#  'textbook',
#  'mood',
#  'affair',
#  'work',
#  'indi',
#  'coupl',
#  'greater',
#  'govt',
#  'icon',
#  'konrath',
#  'young',
#  'whether',
#  'prepar',
#  'age',
#  'ideahow',
#  'khad',
#  'thing',
#  'sailboat',
#  'rabbit',
#  'els',
#  'belov',
#  'child',
#  'dumb',
#  'nice',
#  'machin',
#  'fanci',
#  'drop',
#  'took',
#  'remov',
#  'alic',
#  'caus',
#  'program',
#  'screenm',
#  'sourc',
#  'newer',
#  'decid',
#  'someth',
#  'oper',
#  'take',
#  'cuter',
#  'turn',
#  'contact',
#  'begin',
#  'wheel',
#  'aka',
#  'stuck',
#  'year',
#  'andersalthough',
#  'ereadernot',
#  'grab',
#  'charg',
#  'greatand',
#  'wow',
#  'httpwwwamazoncomsrefnbsbnossurlsearchaliasdapsfieldkeywordsdanielleleezwisslerxi',
#  'wship',
#  'timbukit',
#  'gotten',
#  'start',
#  'local',
#  'possibl',
#  'nassau',
#  'worri',
#  'se',
#  'squar',
#  'sarah',
#  'spring',
#  'default',
#  'warmth',
#  'except',
#  'reliev',
#  'intrigu',
#  'technic',
#  'topic',
#  'manag',
#  'dint',
#  'mail',
#  'clotild',
#  'kindlec',
#  'dude',
#  'gone',
#  'usual',
#  'drive',
#  'teacherstutor',
#  'gym',
#  'upgrad',
#  'creat',
#  'tag',
#  'pregnanc',
#  'today',
#  'let',
#  'communic',
#  'away',
#  'happi',
#  'calm',
#  'kindlemi',
#  'sever',
#  'progress',
#  'special',
#  'clean',
#  'dean',
#  'itali',
#  'legthen',
#  'utter',
#  'voucher',
#  'inpatientbord',
#  'mum',
#  'marri',
#  'cheboygan',
#  'impati',
#  'period',
#  'intimid',
#  'forget',
#  'georgett',
#  'alon',
#  'doesnt',
#  'wing',
#  'here',
#  'andcount',
#  'face',
#  'omiss',
#  'cant',
#  'tree',
#  'readapalooza',
#  'heyer',
#  'static',
#  'makl',
#  'audio',
#  'versa',
#  'awkward',
#  'sub',
#  'togeth',
#  'caveatsi',
#  'twin',
#  'stick',
#  'fan',
#  'entri',
#  'condomsspel',
#  'lit',
#  'project',
#  'imposs',
#  'essenti',
#  'woman',
#  'care',
#  'noth',
#  'fault',
#  'see',
#  'place',
#  'addict',
#  'feel',
#  'dead',
#  'cetatin',
#  'un',
#  'updat',
#  'might',
#  'betsi',
#  'disclos',
#  'leav',
#  'fall',
#  'electron',
#  'xmiami',
#  'hang',
#  'hop',
#  'flippin',
#  'link',
#  'kindlei',
#  'valentin',
#  'stupid',
#  'receiv',
#  'lobbi',
#  'softwarehardwar',
#  'enlarg',
#  'kindlewel',
#  'agenda',
#  'featur',
#  'bread',
#  'clog',
#  'cup',
#  'bulki',
#  'reach',
#  'nylon',
#  'download',
#  'access',
#  'display',
#  'honest',
#  'whim',
#  'pharmaci',
#  'hear',
#  'compani',
#  'conectividad',
#  'pattern',
#  'giant',
#  'beyond',
#  'understand',
#  'em',
#  'search',
#  'childrenit',
#  'gotta',
#  'smoooooch',
#  'tap',
#  'tuck',
#  'dear',
#  'u',
#  'ipadiphonecomput',
#  'goe',
#  'assum',
#  'straightkindl',
#  'couldnt',
#  'simpl',
#  'sister',
#  'loan',
#  'mneim',
#  'ignor',
#  'dora',
#  'game',
#  'pack',
#  'rural',
#  'public',
#  'rediscov',
#  'haha',
#  'butter',
#  'theyll',
#  'baja',
#  'digital',
#  'inexpens',
#  'heavi',
#  'point',
#  'barley',
#  'quiet',
#  'depend',
#  'wikipedia',
#  'lol',
#  'doctor',
#  'yippe',
#  'count',
#  'kindel',
#  'speech',
#  'warm',
#  'summari',
#  'distanc',
#  'ann',
#  'teen',
#  'kindlexxx',
#  'foreign',
#  'loos',
#  'tzw',
#  'done',
#  'sooooo',
#  'ellipticalno',
#  'answer',
#  'libraryno',
#  'exact',
#  'excel',
#  'pragu',
#  'oldest',
#  'tuesday',
#  'thought',
#  'via',
#  'relat',
#  'readingn',
#  'mexico',
#  'teach',
#  'theri',
#  'heart',
#  'free',
#  'lolbut',
#  'delight',
#  'repurpos',
#  'excit',
#  'galaxi',
#  'hole',
#  'helen',
#  'bummer',
#  'danc',
#  'post',
#  'invest',
#  'contracept',
#  'lack',
#  'meow',
#  'piti',
#  'el',
#  'hasslenow',
#  'track',
#  'psych',
#  'peter',
#  'hilit',
#  'quick',
#  'sampl',
#  'hooray',
#  'murder',
#  'robyn',
#  'collectionus',
#  'ownerskindl',
#  'persuad',
#  'watch',
#  'netflix',
#  'satisfi',
#  'settl',
#  'reduc',
#  'mei',
#  'provok',
#  'nope',
#  'seri',
#  'al',
#  'chose',
#  'medium',
#  'suv',
#  'weirdo',
#  'summer',
#  'danger',
#  'linda',
#  'pricey',
#  'menu',
#  'media',
#  'dragana',
#  'main',
#  'onjust',
#  'adventur',
#  'toward',
#  'tedious',
#  'yr',
#  'lookup',
#  'dark',
#  'bedeasi',
#  'android',
#  'reluct',
#  'row',
#  'enabl',
#  'week',
#  'wifi',
#  'everyt',
#  'bookmark',
#  'condom',
#  'purchasedl',
#  'pink',
#  'slot',
#  'scratch',
#  'pleasurenot',
#  'kindleon',
#  'tough',
#  'onesi',
#  'clutter',
#  'kindlethink',
#  'countri',
#  'bulk',
#  'dolov',
#  'popup',
#  'bolton',
#  'archiv',
#  'impress',
#  'promis',
#  'gap',
#  'appear',
#  'crochet',
#  'navig',
#  'give',
#  'anywher',
#  'reali',
#  'plus',
#  'bunch',
#  'sun',
#  'complain',
#  'tini',
#  'loud',
#  'confid',
#  'pay',
#  'charl',
#  'bore',
#  'lend',
#  'simpler',
#  'convinc',
#  'someon',
#  'allevi',
#  'bundl',
#  'cutron',
#  'afterward',
#  'either',
#  'youll',
#  'andi',
#  'italian',
#  'nonexist',
#  'check',
#  'cring',
#  'glori',
#  'birthday',
#  'translat',
#  'os',
#  'clown',
#  'part',
#  'hand',
#  'everyday',
#  'lori',
#  'pocket',
#  'saul',
#  'whoa',
#  'retriev',
#  'expens',
#  'mobl',
#  'e',
#  'chockablock',
#  'custom',
#  'avenu',
#  'itgo',
#  'move',
#  'font',
#  'kl',
#  'hardback',
#  'poor',
#  'kathyti',
#  'ny',
#  'darn',
#  'snuggl',
#  'bind',
#  'sweet',
#  'found',
#  'nonfict',
#  'alreadi',
#  'tracker',
#  'one',
#  'andmuch',
#  'sooner',
#  'grati',
#  'mild',
#  'trip',
#  'fish',
#  'tech',
#  'appt',
#  'p',
#  'aesop',
#  'saw',
#  'dr',
#  'lesli',
#  'format',
#  'floor',
#  'back',
#  'appreci',
#  'pic',
#  'nook',
#  'friend',
#  'use',
#  'facebook',
#  'traepischk',
#  'card',
#  'spell',
#  'por',
#  'defreez',
#  'along',
#  'microphon',
#  'gt',
#  'fic',
#  '♥',
#  'forest',
#  'reset',
#  'dianeal',
#  'tast',
#  'present',
#  'fibromyalgia',
#  'payrol',
#  'gifti',
#  'selfpublish',
#  'newest',
#  'hangman',
#  'surround',
#  'til',
#  'spot',
#  'follett',
#  'make',
#  'differ',
#  'letter',
#  'howwhat',
#  'serious',
#  'devic',
#  'favor',
#  'tien',
#  'nake',
#  'trust',
#  'forward',
#  'import',
#  'frist',
#  'id',
#  'peopl',
#  'think',
#  'sky',
#  'favourit',
#  'helpful',
#  'camaflag',
#  'disappear',
#  'lost',
#  'store',
#  'almost',
#  'tongueincheek',
#  'kindleit',
#  'articlethought',
#  'magazinesand',
#  'kindlealthough',
#  'know',
#  'essenc',
#  'screen',
#  'have',
#  'handl',
#  'renew',
#  'kind',
#  'nap',
#  'time',
#  'apart',
#  'itbtw',
#  'speak',
#  'adult',
#  'song',
#  'cover',
#  'smell',
#  'hunger',
#  'middl',
#  'touch',
#  'matur',
#  'bump',
#  'transport',
#  'shoulder',
#  'pet',
#  'cozi',
#  'nk',
#  'must',
#  'attorney',
#  'sni',
#  'wwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt',
#  'octob',
#  'lot',
#  'timbuk',
#  'late',
#  'pdf',
#  'tire',
#  'casejust',
#  'tredmil',
#  'ghost',
#  'patterson',
#  'ebay',
#  'webi',
#  'pictur',
#  'round',
#  'load',
#  'offens',
#  'delet',
#  'keep',
#  'belkin',
#  'sleev',
#  'pullout',
#  'sport',
#  'accompani',
#  'sign',
#  'downloadedand',
#  'niec',
#  'amount',
#  'deregist',
#  'anoth',
#  'potenti',
#  'occasion',
#  'counti',
#  'aw',
#  'love',
#  'headach',
#  'facil',
#  'ooz',
#  'job',
#  'shame',
#  'sent',
#  'deal',
#  'realiz',
#  'basic',
#  'tale',
#  'ask',
#  'bday',
#  'k',
#  'touchscreen',
#  'bodi',
#  'greyi',
#  'intern',
#  'batteri',
#  'pandigit',
#  'vice',
#  'r',
#  'oen',
#  'im',
#  'ride',
#  'hotspot',
#  'oooh',
#  'pitch',
#  'vegan',
#  'adoro',
#  'everrrrrr',
#  'scenario',
#  'handi',
#  'widen',
#  'en',
#  'probabl',
#  'exampl',
#  'perhap',
#  'elsewher',
#  'gutenberg',
#  'otherwis',
#  'multipl',
#  'shouldnt',
#  'mundo',
#  'level',
#  'usb',
#  'kindlepleas',
#  'question',
#  'amigo',
#  'effort',
#  'servic',
#  'half',
#  'send',
#  'gag',
#  'nativ',
#  'clearer',
#  'america',
#  'still',
#  'officekindl',
#  'research',
#  'percentag',
#  'side',
#  'school',
#  'treasur',
#  'short',
#  'spoon',
#  'pueden',
#  'schmanci',
#  'huh',
#  'inconveni',
#  'agolol',
#  'constant',
#  'que',
#  'moran',
#  'publish',
#  'happier',
#  'brought',
#  'improv',
#  'aww',
#  'nurs',
#  'cours',
#  'riley',
#  'rip',
#  'finess',
#  'defin',
#  'author',
#  'bed',
#  'uncl',
#  'notic',
#  'dresser',
#  'ok',
#  'return',
#  'minut',
#  'cradl',
#  'negat',
#  'frenchamerican',
#  'bedroom',
#  'entir',
#  'worldschool',
#  'nobl',
#  'help',
#  'trolley',
#  'next',
#  'towanna',
#  'internet',
#  'exorcis',
#  'fiction',
#  'less',
#  'pointycorn',
#  'anymor',
#  'revolut',
#  'drawback',
#  'variant',
#  'two',
#  'wear',
#  'hey',
#  'froze',
#  'dozen',
#  'spoil',
#  'softwar',
#  'prize',
#  'est',
#  'trade',
#  'save',
#  'hate',
#  'arent',
#  'min',
#  'idea',
#  'nonamerican',
#  'joke',
#  'most',
#  'popular',
#  'thick',
#  'loi',
#  'wasnt',
#  'suck',
#  'pentz',
#  'instruct',
#  'camopinkcamo',
#  'damag',
#  'sameth',
#  'educ',
#  'workno',
#  'formatgrrgrrnot',
#  'sled',
#  'rid',
#  'morn',
#  'opinion',
#  'other',
#  'perpetu',
#  'songwrit',
#  'copi',
#  'alleven',
#  'fit',
#  'librari',
#  'rest',
#  'final',
#  'coolest',
#  'finger',
#  'phrase',
#  'laptop',
#  'ecstat',
#  'compat',
#  'recumbr',
#  'osteoarthr',
#  'ghetto',
#  'retir',
#  'scott',
#  'gazillion',
#  'capabl',
#  'creepi',
#  'fingur',
#  'daili',
#  'edit',
#  'cursor',
#  'featuregot',
#  'novic',
#  'eh',
#  'problem',
#  'phylli',
#  'club',
#  '´',
#  'fifth',
#  'way',
#  'gear',
#  'us',
#  'built',
#  'director',
#  'standalon',
#  'wo',
#  'toggl',
#  'huge',
#  'deserv',
#  'spam',
#  'clanci',
#  'panera',
#  'teas',
#  'motorhom',
#  'nois',
#  'real',
#  'colorless',
#  'dine',
#  'redgrayblack',
#  'realiti',
#  'chanc',
#  'waumgauh',
#  'tradit',
#  'patient',
#  'especi',
#  'backup',
#  'men',
#  'luck',
#  'downon',
#  'latest',
#  'dust',
#  'catch',
#  'date',
#  'suppos',
#  'gameseven',
#  'clara',
#  'archivei',
#  'schoolbook',
#  'idiot',
#  'buse',
#  'cabin',
#  'magic',
#  'rock',
#  'hes',
#  'third',
#  'bring',
#  'tone',
#  'front',
#  'bought',
#  'kolan',
#  'seen',
#  'hi',
#  'hoo',
#  'snider',
#  'pop',
#  'router',
#  'discov',
#  'perman',
#  'buri',
#  ...}

# %%
dd = pd.DataFrame(columns=dic)

# %%
x=[s in final_X[0] for s in dic]

# %%
present=[]
for r in final_X:
  x=[s in r for s in dic]
  present.append(x)

# %%
len(present)
# Out:
# 1003

# %%
df2=pd.DataFrame(present,columns=dic)

# %%
df2.head()
# Out:
#    compet   over  spark  weird  shakespear  holiday  write  confino   cash  \
# 0   False  False  False  False       False    False  False    False  False
# 1   False  False  False  False       False    False  False    False  False
# 2   False  False  False  False       False    False  False    False  False
# 3   False  False  False  False       False    False  False    False  False
# 4   False  False  False  False       False    False  False    False  False
#
#    shark    ...      struggl  wonderland    run    man  tampoco  without  \
# 0  False    ...        False       False  False  False    False    False
# 1  False    ...        False       False  False   True    False    False
# 2  False    ...        False       False  False  False    False    False
# 3  False    ...        False       False  False  False    False    False
# 4  False    ...        False       False  False  False    False    False
#
#    magazin      w  stricken  daugjhter
# 0    False  False     False      False
# 1    False  False     False      False
# 2    False  False     False      False
# 3    False  False     False      False
# 4    False  False     False      False
#
# [5 rows x 2323 columns]

# %%
df2.iloc[0]['drug']
# Out:
# True

# %%
dic
# Out:
# {'compet',
#  'over',
#  'spark',
#  'weird',
#  'shakespear',
#  'holiday',
#  'write',
#  'confino',
#  'cash',
#  'shark',
#  'mmm',
#  'referenc',
#  'twice',
#  'old',
#  'ortho',
#  'scari',
#  'ellipt',
#  'immedi',
#  'kindlecr',
#  'beat',
#  'ra',
#  'even',
#  'open',
#  'builtin',
#  'lover',
#  'crumb',
#  'shape',
#  'interest',
#  'written',
#  'book',
#  'lesson',
#  'made',
#  'leap',
#  'wall',
#  'refer',
#  'oxford',
#  'itd',
#  'bang',
#  'st',
#  'communiti',
#  'experienc',
#  'jodi',
#  'jeff',
#  'wonder',
#  'stress',
#  'imagin',
#  'simpli',
#  'ukrainian',
#  'crackl',
#  'mayb',
#  'accessori',
#  'sit',
#  'kindlemayb',
#  'ideasomebodi',
#  'adquirido',
#  'stroj',
#  'superior',
#  'fabric',
#  'son',
#  'island',
#  'rep',
#  'enter',
#  'clear',
#  'sept',
#  'upon',
#  'cyr',
#  'treadmil',
#  'fussi',
#  'mejor',
#  'curs',
#  'stroll',
#  'thumbnail',
#  'could',
#  'snow',
#  'todo',
#  'futur',
#  'noooo',
#  'nd',
#  'within',
#  'chair',
#  'act',
#  'hurt',
#  'annoy',
#  'surpris',
#  'involv',
#  'feminin',
#  'hit',
#  'anna',
#  'talk',
#  'graduat',
#  'wife',
#  'safe',
#  'omgi',
#  'ive',
#  'convert',
#  'spend',
#  'archaic',
#  'section',
#  'doabl',
#  'sort',
#  'floater',
#  'drain',
#  'thirst',
#  'pg',
#  'artwork',
#  'area',
#  'goa',
#  'stephani',
#  'head',
#  'breastfeed',
#  'second',
#  'skill',
#  'profil',
#  'flash',
#  'fetish',
#  'concern',
#  'propos',
#  'offic',
#  'screensav',
#  'juli',
#  'collect',
#  'cj',
#  'challeng',
#  'popul',
#  'easili',
#  'snap',
#  'umhow',
#  'tout',
#  'web',
#  'regard',
#  'name',
#  'frame',
#  'incom',
#  'singl',
#  'illiter',
#  'five',
#  'memori',
#  'companion',
#  'bit',
#  'defect',
#  'mode',
#  'prevent',
#  'canada',
#  'hurdl',
#  'compu',
#  'spent',
#  'consol',
#  'autobiographi',
#  'thriller',
#  'fashion',
#  'text',
#  'experi',
#  'somewher',
#  'version',
#  'plastic',
#  'that',
#  'foam',
#  'readinglol',
#  'matter',
#  'mean',
#  'altern',
#  'keurig',
#  'skip',
#  'backlight',
#  'russian',
#  'market',
#  'possess',
#  'childrenthank',
#  'provid',
#  'last',
#  'slight',
#  'neat',
#  'discomfort',
#  'easi',
#  'onto',
#  'honey',
#  'complic',
#  'soo',
#  'havent',
#  'increas',
#  'cost',
#  'pain',
#  'drs',
#  'koontz',
#  'sew',
#  'forc',
#  'averag',
#  'smile',
#  'pool',
#  'never',
#  'tooif',
#  'eye',
#  'alphabet',
#  'thnx',
#  'kindlemak',
#  'dx',
#  'wellthi',
#  'yes',
#  'happend',
#  'instinct',
#  'textbook',
#  'mood',
#  'affair',
#  'work',
#  'indi',
#  'coupl',
#  'greater',
#  'govt',
#  'icon',
#  'konrath',
#  'young',
#  'whether',
#  'prepar',
#  'age',
#  'ideahow',
#  'khad',
#  'thing',
#  'sailboat',
#  'rabbit',
#  'els',
#  'belov',
#  'child',
#  'dumb',
#  'nice',
#  'machin',
#  'fanci',
#  'drop',
#  'took',
#  'remov',
#  'alic',
#  'caus',
#  'program',
#  'screenm',
#  'sourc',
#  'newer',
#  'decid',
#  'someth',
#  'oper',
#  'take',
#  'cuter',
#  'turn',
#  'contact',
#  'begin',
#  'wheel',
#  'aka',
#  'stuck',
#  'year',
#  'andersalthough',
#  'ereadernot',
#  'grab',
#  'charg',
#  'greatand',
#  'wow',
#  'httpwwwamazoncomsrefnbsbnossurlsearchaliasdapsfieldkeywordsdanielleleezwisslerxi',
#  'wship',
#  'timbukit',
#  'gotten',
#  'start',
#  'local',
#  'possibl',
#  'nassau',
#  'worri',
#  'se',
#  'squar',
#  'sarah',
#  'spring',
#  'default',
#  'warmth',
#  'except',
#  'reliev',
#  'intrigu',
#  'technic',
#  'topic',
#  'manag',
#  'dint',
#  'mail',
#  'clotild',
#  'kindlec',
#  'dude',
#  'gone',
#  'usual',
#  'drive',
#  'teacherstutor',
#  'gym',
#  'upgrad',
#  'creat',
#  'tag',
#  'pregnanc',
#  'today',
#  'let',
#  'communic',
#  'away',
#  'happi',
#  'calm',
#  'kindlemi',
#  'sever',
#  'progress',
#  'special',
#  'clean',
#  'dean',
#  'itali',
#  'legthen',
#  'utter',
#  'voucher',
#  'inpatientbord',
#  'mum',
#  'marri',
#  'cheboygan',
#  'impati',
#  'period',
#  'intimid',
#  'forget',
#  'georgett',
#  'alon',
#  'doesnt',
#  'wing',
#  'here',
#  'andcount',
#  'face',
#  'omiss',
#  'cant',
#  'tree',
#  'readapalooza',
#  'heyer',
#  'static',
#  'makl',
#  'audio',
#  'versa',
#  'awkward',
#  'sub',
#  'togeth',
#  'caveatsi',
#  'twin',
#  'stick',
#  'fan',
#  'entri',
#  'condomsspel',
#  'lit',
#  'project',
#  'imposs',
#  'essenti',
#  'woman',
#  'care',
#  'noth',
#  'fault',
#  'see',
#  'place',
#  'addict',
#  'feel',
#  'dead',
#  'cetatin',
#  'un',
#  'updat',
#  'might',
#  'betsi',
#  'disclos',
#  'leav',
#  'fall',
#  'electron',
#  'xmiami',
#  'hang',
#  'hop',
#  'flippin',
#  'link',
#  'kindlei',
#  'valentin',
#  'stupid',
#  'receiv',
#  'lobbi',
#  'softwarehardwar',
#  'enlarg',
#  'kindlewel',
#  'agenda',
#  'featur',
#  'bread',
#  'clog',
#  'cup',
#  'bulki',
#  'reach',
#  'nylon',
#  'download',
#  'access',
#  'display',
#  'honest',
#  'whim',
#  'pharmaci',
#  'hear',
#  'compani',
#  'conectividad',
#  'pattern',
#  'giant',
#  'beyond',
#  'understand',
#  'em',
#  'search',
#  'childrenit',
#  'gotta',
#  'smoooooch',
#  'tap',
#  'tuck',
#  'dear',
#  'u',
#  'ipadiphonecomput',
#  'goe',
#  'assum',
#  'straightkindl',
#  'couldnt',
#  'simpl',
#  'sister',
#  'loan',
#  'mneim',
#  'ignor',
#  'dora',
#  'game',
#  'pack',
#  'rural',
#  'public',
#  'rediscov',
#  'haha',
#  'butter',
#  'theyll',
#  'baja',
#  'digital',
#  'inexpens',
#  'heavi',
#  'point',
#  'barley',
#  'quiet',
#  'depend',
#  'wikipedia',
#  'lol',
#  'doctor',
#  'yippe',
#  'count',
#  'kindel',
#  'speech',
#  'warm',
#  'summari',
#  'distanc',
#  'ann',
#  'teen',
#  'kindlexxx',
#  'foreign',
#  'loos',
#  'tzw',
#  'done',
#  'sooooo',
#  'ellipticalno',
#  'answer',
#  'libraryno',
#  'exact',
#  'excel',
#  'pragu',
#  'oldest',
#  'tuesday',
#  'thought',
#  'via',
#  'relat',
#  'readingn',
#  'mexico',
#  'teach',
#  'theri',
#  'heart',
#  'free',
#  'lolbut',
#  'delight',
#  'repurpos',
#  'excit',
#  'galaxi',
#  'hole',
#  'helen',
#  'bummer',
#  'danc',
#  'post',
#  'invest',
#  'contracept',
#  'lack',
#  'meow',
#  'piti',
#  'el',
#  'hasslenow',
#  'track',
#  'psych',
#  'peter',
#  'hilit',
#  'quick',
#  'sampl',
#  'hooray',
#  'murder',
#  'robyn',
#  'collectionus',
#  'ownerskindl',
#  'persuad',
#  'watch',
#  'netflix',
#  'satisfi',
#  'settl',
#  'reduc',
#  'mei',
#  'provok',
#  'nope',
#  'seri',
#  'al',
#  'chose',
#  'medium',
#  'suv',
#  'weirdo',
#  'summer',
#  'danger',
#  'linda',
#  'pricey',
#  'menu',
#  'media',
#  'dragana',
#  'main',
#  'onjust',
#  'adventur',
#  'toward',
#  'tedious',
#  'yr',
#  'lookup',
#  'dark',
#  'bedeasi',
#  'android',
#  'reluct',
#  'row',
#  'enabl',
#  'week',
#  'wifi',
#  'everyt',
#  'bookmark',
#  'condom',
#  'purchasedl',
#  'pink',
#  'slot',
#  'scratch',
#  'pleasurenot',
#  'kindleon',
#  'tough',
#  'onesi',
#  'clutter',
#  'kindlethink',
#  'countri',
#  'bulk',
#  'dolov',
#  'popup',
#  'bolton',
#  'archiv',
#  'impress',
#  'promis',
#  'gap',
#  'appear',
#  'crochet',
#  'navig',
#  'give',
#  'anywher',
#  'reali',
#  'plus',
#  'bunch',
#  'sun',
#  'complain',
#  'tini',
#  'loud',
#  'confid',
#  'pay',
#  'charl',
#  'bore',
#  'lend',
#  'simpler',
#  'convinc',
#  'someon',
#  'allevi',
#  'bundl',
#  'cutron',
#  'afterward',
#  'either',
#  'youll',
#  'andi',
#  'italian',
#  'nonexist',
#  'check',
#  'cring',
#  'glori',
#  'birthday',
#  'translat',
#  'os',
#  'clown',
#  'part',
#  'hand',
#  'everyday',
#  'lori',
#  'pocket',
#  'saul',
#  'whoa',
#  'retriev',
#  'expens',
#  'mobl',
#  'e',
#  'chockablock',
#  'custom',
#  'avenu',
#  'itgo',
#  'move',
#  'font',
#  'kl',
#  'hardback',
#  'poor',
#  'kathyti',
#  'ny',
#  'darn',
#  'snuggl',
#  'bind',
#  'sweet',
#  'found',
#  'nonfict',
#  'alreadi',
#  'tracker',
#  'one',
#  'andmuch',
#  'sooner',
#  'grati',
#  'mild',
#  'trip',
#  'fish',
#  'tech',
#  'appt',
#  'p',
#  'aesop',
#  'saw',
#  'dr',
#  'lesli',
#  'format',
#  'floor',
#  'back',
#  'appreci',
#  'pic',
#  'nook',
#  'friend',
#  'use',
#  'facebook',
#  'traepischk',
#  'card',
#  'spell',
#  'por',
#  'defreez',
#  'along',
#  'microphon',
#  'gt',
#  'fic',
#  '♥',
#  'forest',
#  'reset',
#  'dianeal',
#  'tast',
#  'present',
#  'fibromyalgia',
#  'payrol',
#  'gifti',
#  'selfpublish',
#  'newest',
#  'hangman',
#  'surround',
#  'til',
#  'spot',
#  'follett',
#  'make',
#  'differ',
#  'letter',
#  'howwhat',
#  'serious',
#  'devic',
#  'favor',
#  'tien',
#  'nake',
#  'trust',
#  'forward',
#  'import',
#  'frist',
#  'id',
#  'peopl',
#  'think',
#  'sky',
#  'favourit',
#  'helpful',
#  'camaflag',
#  'disappear',
#  'lost',
#  'store',
#  'almost',
#  'tongueincheek',
#  'kindleit',
#  'articlethought',
#  'magazinesand',
#  'kindlealthough',
#  'know',
#  'essenc',
#  'screen',
#  'have',
#  'handl',
#  'renew',
#  'kind',
#  'nap',
#  'time',
#  'apart',
#  'itbtw',
#  'speak',
#  'adult',
#  'song',
#  'cover',
#  'smell',
#  'hunger',
#  'middl',
#  'touch',
#  'matur',
#  'bump',
#  'transport',
#  'shoulder',
#  'pet',
#  'cozi',
#  'nk',
#  'must',
#  'attorney',
#  'sni',
#  'wwwamazoncomcircumstantialevidencegettingfloridabozarthebookdpbfpzrefpdrhfpt',
#  'octob',
#  'lot',
#  'timbuk',
#  'late',
#  'pdf',
#  'tire',
#  'casejust',
#  'tredmil',
#  'ghost',
#  'patterson',
#  'ebay',
#  'webi',
#  'pictur',
#  'round',
#  'load',
#  'offens',
#  'delet',
#  'keep',
#  'belkin',
#  'sleev',
#  'pullout',
#  'sport',
#  'accompani',
#  'sign',
#  'downloadedand',
#  'niec',
#  'amount',
#  'deregist',
#  'anoth',
#  'potenti',
#  'occasion',
#  'counti',
#  'aw',
#  'love',
#  'headach',
#  'facil',
#  'ooz',
#  'job',
#  'shame',
#  'sent',
#  'deal',
#  'realiz',
#  'basic',
#  'tale',
#  'ask',
#  'bday',
#  'k',
#  'touchscreen',
#  'bodi',
#  'greyi',
#  'intern',
#  'batteri',
#  'pandigit',
#  'vice',
#  'r',
#  'oen',
#  'im',
#  'ride',
#  'hotspot',
#  'oooh',
#  'pitch',
#  'vegan',
#  'adoro',
#  'everrrrrr',
#  'scenario',
#  'handi',
#  'widen',
#  'en',
#  'probabl',
#  'exampl',
#  'perhap',
#  'elsewher',
#  'gutenberg',
#  'otherwis',
#  'multipl',
#  'shouldnt',
#  'mundo',
#  'level',
#  'usb',
#  'kindlepleas',
#  'question',
#  'amigo',
#  'effort',
#  'servic',
#  'half',
#  'send',
#  'gag',
#  'nativ',
#  'clearer',
#  'america',
#  'still',
#  'officekindl',
#  'research',
#  'percentag',
#  'side',
#  'school',
#  'treasur',
#  'short',
#  'spoon',
#  'pueden',
#  'schmanci',
#  'huh',
#  'inconveni',
#  'agolol',
#  'constant',
#  'que',
#  'moran',
#  'publish',
#  'happier',
#  'brought',
#  'improv',
#  'aww',
#  'nurs',
#  'cours',
#  'riley',
#  'rip',
#  'finess',
#  'defin',
#  'author',
#  'bed',
#  'uncl',
#  'notic',
#  'dresser',
#  'ok',
#  'return',
#  'minut',
#  'cradl',
#  'negat',
#  'frenchamerican',
#  'bedroom',
#  'entir',
#  'worldschool',
#  'nobl',
#  'help',
#  'trolley',
#  'next',
#  'towanna',
#  'internet',
#  'exorcis',
#  'fiction',
#  'less',
#  'pointycorn',
#  'anymor',
#  'revolut',
#  'drawback',
#  'variant',
#  'two',
#  'wear',
#  'hey',
#  'froze',
#  'dozen',
#  'spoil',
#  'softwar',
#  'prize',
#  'est',
#  'trade',
#  'save',
#  'hate',
#  'arent',
#  'min',
#  'idea',
#  'nonamerican',
#  'joke',
#  'most',
#  'popular',
#  'thick',
#  'loi',
#  'wasnt',
#  'suck',
#  'pentz',
#  'instruct',
#  'camopinkcamo',
#  'damag',
#  'sameth',
#  'educ',
#  'workno',
#  'formatgrrgrrnot',
#  'sled',
#  'rid',
#  'morn',
#  'opinion',
#  'other',
#  'perpetu',
#  'songwrit',
#  'copi',
#  'alleven',
#  'fit',
#  'librari',
#  'rest',
#  'final',
#  'coolest',
#  'finger',
#  'phrase',
#  'laptop',
#  'ecstat',
#  'compat',
#  'recumbr',
#  'osteoarthr',
#  'ghetto',
#  'retir',
#  'scott',
#  'gazillion',
#  'capabl',
#  'creepi',
#  'fingur',
#  'daili',
#  'edit',
#  'cursor',
#  'featuregot',
#  'novic',
#  'eh',
#  'problem',
#  'phylli',
#  'club',
#  '´',
#  'fifth',
#  'way',
#  'gear',
#  'us',
#  'built',
#  'director',
#  'standalon',
#  'wo',
#  'toggl',
#  'huge',
#  'deserv',
#  'spam',
#  'clanci',
#  'panera',
#  'teas',
#  'motorhom',
#  'nois',
#  'real',
#  'colorless',
#  'dine',
#  'redgrayblack',
#  'realiti',
#  'chanc',
#  'waumgauh',
#  'tradit',
#  'patient',
#  'especi',
#  'backup',
#  'men',
#  'luck',
#  'downon',
#  'latest',
#  'dust',
#  'catch',
#  'date',
#  'suppos',
#  'gameseven',
#  'clara',
#  'archivei',
#  'schoolbook',
#  'idiot',
#  'buse',
#  'cabin',
#  'magic',
#  'rock',
#  'hes',
#  'third',
#  'bring',
#  'tone',
#  'front',
#  'bought',
#  'kolan',
#  'seen',
#  'hi',
#  'hoo',
#  'snider',
#  'pop',
#  'router',
#  'discov',
#  'perman',
#  'buri',
#  ...}

# %%
labels[1]
# Out:
# ''

# %%
len(labels)
# Out:
# 1999

# %%
for x in labels:
  if(x==''):
    labels.remove(x)

# %%
labels
# Out:
# ['O',
#  'O',
#  'O',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'P',
#  'O',
#  'O',
#  'N',
#  'O',
#  'N',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'N',
#  'N',
#  'P',
#  'P',
#  'N',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'N',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'N',
#  'N',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'P',
#  'N',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'N',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'O',
#  'P',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'N',
#  'P',
#  'N',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'O',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'O',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'N',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'N',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'N',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'O',
#  'P',
#  'O',
#  'O',
#  'N',
#  'P',
#  'N',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'N',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'O',
#  'N',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'O',
#  'O',
#  'O',
#  'O',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'N',
#  'O',
#  'O',
#  'N',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'N',
#  'P',
#  'P',
#  'O',
#  'N',
#  'P',
#  'N',
#  'P',
#  'O',
#  'N',
#  'P',
#  'N',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'N',
#  'N',
#  'O',
#  'O',
#  'P',
#  'N',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'O',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'O',
#  'P',
#  'N',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'P',
#  'P',
#  'O',
#  'P',
#  'O',
#  'N',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'N',
#  'P']

# %%
df2['out'] = labels
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-4beb6b5b21d6> in <module>()
# ----> 1 df2['out'] = labels
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
#    2759             # turn me into an ndarray
# -> 2760             value = _sanitize_index(value, self.index, copy=False)
#    2761             if not isinstance(value, (np.ndarray, Index)):
#    2762                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3119
#    3120     if len(data) != len(index):
# -> 3121         raise ValueError('Length of values does not match length of ' 'index')
#    3122
#    3123     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
mylist[1000]
# Out:
# 'kindle  is such a great product i could not be happier with mine'

# %%
labels.extend(['P','N','P'])

# %%
with open('fb_label.txt') as f:
    labe = [line.rstrip('\n') for line in f]

# %%
lab=[line.rstrip('') for line in labe]

# %%
df2.to_csv('file_name2.csv', sep=',')

# %%
df2['out']=labels

# %%
df2.head()
# Out:
#    compet   over  spark  weird  shakespear  holiday  write  confino   cash  \
# 0   False  False  False  False       False    False  False    False  False
# 1   False  False  False  False       False    False  False    False  False
# 2   False  False  False  False       False    False  False    False  False
# 3   False  False  False  False       False    False  False    False  False
# 4   False  False  False  False       False    False  False    False  False
#
#    shark ...   wonderland    run    man  tampoco  without  magazin      w  \
# 0  False ...        False  False  False    False    False    False  False
# 1  False ...        False  False   True    False    False    False  False
# 2  False ...        False  False  False    False    False    False  False
# 3  False ...        False  False  False    False    False    False  False
# 4  False ...        False  False  False    False    False    False  False
#
#    stricken  daugjhter  out
# 0     False      False    O
# 1     False      False    O
# 2     False      False    O
# 3     False      False    O
# 4     False      False    N
#
# [5 rows x 2324 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
import time

# %%
X_train, X_test = train_test_split(df2, test_size=0.1, random_state=int(time.time()))

# %%
gnb = GaussianNB()
gnb.fit(
    X_train[dic2].values,
    X_train["out"]
)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
dic2=list(dic)

# %%
y_pred = gnb.predict(X_test[dic2])

# %%
print("Number of mislabeled points out of a total {} points : {}, performance {:05.2f}%"
      .format(
          X_test.shape[0],
          (X_test["out"] != y_pred).sum(),
          100*(1-(X_test["out"] != y_pred).sum()/X_test.shape[0])
))
# Out:
# Number of mislabeled points out of a total 101 points : 64, performance 36.63%
